# %% [markdown]
# # How the world's biggest democracy voted in 2019!

# %% [markdown]
# # Introduction:
#
# The Constitution of India, which establishes the division of power between the federal government and the states, governs the nation of India, which comprises states and union territories. The Election Commission is a federal organization established in accordance with the Constitution and is in charge of overseeing and regulating all Indian election procedures. This organization is in charge of ensuring impartial, fair, and free elections.
# The lower house of India's parliament, Lok Sabha, or the House of the People, is chosen by adult Indian citizens from a field of candidates who run in their individual seats. The analysis presented here is based on the Lok Sabha election (The General Elections) for the year 2019. Only their constituency is open to adult citizens of India. Winners of the Lok Sabha elections are referred to as "Members of Parliament," and they retain their positions for five years or until the President, acting on the recommendation of the cabinet, dissolves the body. On issues pertaining to the creation of new laws, removing or improving the existing laws that affect all citizens of India. The house meets in the Lok Sabha Chambers of the Sansad Bhavan in New Delhi.
#
# ### Objective:
#
# Using the data of 2019 Loksabha Elections, we aim to perform data cleaning and data wrangling tasks on it. We will also analyze the data for exploratory data analysis using matplotlib , seaborn,plotly,etc.
# Our end goal is to predict the winner of the elections using EDA and ML prediction algorithms.
#
# ### About the Dataset:
#
# The dataset consists of 2263 rows and 19 columns.
#
# It has 9 “object” type columns, 3 “float” type and 7 “integer” type columns. There are columns like:
# 1) State- State from where candidate contested the election
#
# 2) Constituency- Constituency from where candidate contested the election
#
# 3) Name of candidate
#
# 4) Winner - this column is giving the result in boolean form if the candidate wins it shows 1 else it shows 0
#
# 5) Party- Name of the party of the candidate.
#
# 6) Symbol- respective party symbol
#
# 7) Gender
#
# 8) Criminal Cases- shows number of criminal cases(if any) against the candidate
#
# 9) Age- age of the candidate
#
# 10) Category- Gives the category such as general,st,sc,etc.
#
# 11) Education- Shows the education level of the candidate.
#
# 12) Assets- Contains the amount for the assets owned by the candidate.
#
# 13) Liabilities-  Contains the amount for the liabilities owned by the candidate.
#
# 14) Votes- Total number of votes casted.

# %% [markdown]
# ## Read and Clean
# How about we follow the 5 stage information science process - assemble, survey, clean, break down, imagine, and model. In this specific segment, we'll manage the initial three stages. We'll initially stack our information, check specific credits like number of lines, sections, kinds of factors, etc. After this, we'll search for missing qualities and tidy up any qualities which are not addressed accurately.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ## Importing required libraries and modules.

# %%
import pandas as pd
from sklearn.impute import KNNImputer

# %% [markdown]
# ## Reading the dataset !

# %%
df=pd.read_csv("LS_2.0.csv")

# %%
df
# Out:
#               STATE     CONSTITUENCY                   NAME  WINNER PARTY  \
# 0         Telangana         ADILABAD         SOYAM BAPU RAO       1   BJP
# 1         Telangana         ADILABAD           Godam Nagesh       0   TRS
# 2         Telangana         ADILABAD          RATHOD RAMESH       0   INC
# 3         Telangana         ADILABAD                   NOTA       0  NOTA
# 4     Uttar Pradesh             AGRA  Satyapal Singh Baghel       1   BJP
# ...             ...              ...                    ...     ...   ...
# 2258    Maharashtra  YAVATMAL-WASHIM     Anil Jayram Rathod       0   IND
# 2259      Telangana        ZAHIRABAD              B.B.PATIL       1   TRS
# 2260      Telangana        ZAHIRABAD        MADAN MOHAN RAO       0   INC
# 2261      Telangana        ZAHIRABAD     BANALA LAXMA REDDY       0   BJP
# 2262      Telangana        ZAHIRABAD                   NOTA       0  NOTA
#
#      SYMBOL GENDER CRIMINAL\nCASES   AGE CATEGORY      EDUCATION  \
# 0     Lotus   MALE              52  52.0       ST      12th Pass
# 1       Car   MALE               0  54.0       ST  Post Graduate
# 2      Hand   MALE               3  52.0       ST      12th Pass
# 3       NaN    NaN             NaN   NaN      NaN            NaN
# 4     Lotus   MALE               5  58.0       SC      Doctorate
# ...     ...    ...             ...   ...      ...            ...
# 2258   SHIP   MALE               0  43.0  GENERAL  Post Graduate
# 2259    Car   MALE              18  63.0  GENERAL       Graduate
# 2260   Hand   MALE               0  49.0  GENERAL  Post Graduate
# 2261  Lotus   MALE               3  47.0  GENERAL      12th Pass
# 2262    NaN    NaN             NaN   NaN      NaN            NaN
#
#                                 ASSETS                  LIABILITIES  \
# 0            Rs 30,99,414\n ~ 30 Lacs+      Rs 2,31,450\n ~ 2 Lacs+
# 1          Rs 1,84,77,888\n ~ 1 Crore+      Rs 8,47,000\n ~ 8 Lacs+
# 2          Rs 3,64,91,000\n ~ 3 Crore+  Rs 1,53,00,000\n ~ 1 Crore+
# 3                                  NaN                          NaN
# 4          Rs 7,42,74,036\n ~ 7 Crore+    Rs 86,06,522\n ~ 86 Lacs+
# ...                                ...                          ...
# 2258         Rs 48,90,000\n ~ 48 Lacs+    Rs 10,20,000\n ~ 10 Lacs+
# 2259  Rs 1,28,78,51,556\n ~ 128 Crore+  Rs 1,15,35,000\n ~ 1 Crore+
# 2260     Rs 90,36,63,001\n ~ 90 Crore+                     Rs 0\n ~
# 2261       Rs 5,85,77,327\n ~ 5 Crore+    Rs 52,50,000\n ~ 52 Lacs+
# 2262                               NaN                          NaN
#
#       GENERAL\nVOTES  POSTAL\nVOTES  TOTAL\nVOTES  \
# 0             376892            482        377374
# 1             318665            149        318814
# 2             314057            181        314238
# 3              13030              6         13036
# 4             644459           2416        646875
# ...              ...            ...           ...
# 2258           14661             25         14686
# 2259          434066            178        434244
# 2260          427900            115        428015
# 2261          138731            216        138947
# 2262           11138              2         11140
#
#       OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# 0                                 25.330684
# 1                                 21.399929
# 2                                 21.092771
# 3                                  0.875023
# 4                                 33.383823
# ...                                     ...
# 2258                               0.766419
# 2259                              28.975369
# 2260                              28.559732
# 2261                               9.271379
# 2262                               0.743328
#
#       OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  TOTAL ELECTORS
# 0                                     35.468248         1489790
# 1                                     29.964370         1489790
# 2                                     29.534285         1489790
# 3                                      1.225214         1489790
# 4                                     56.464615         1937690
# ...                                         ...             ...
# 2258                                   1.250060         1916185
# 2259                                  41.574183         1498666
# 2260                                  40.977823         1498666
# 2261                                  13.302678         1498666
# 2262                                   1.066535         1498666
#
# [2263 rows x 19 columns]

# %% [markdown]
# ## Checking for the shape of dataframe

# %%
df.shape
# Out:
# (2263, 19)

# %% [markdown]
# ## Describing the dataset

# %%
df.describe()
# Out:
#             WINNER          AGE  GENERAL\nVOTES  POSTAL\nVOTES  TOTAL\nVOTES  \
# count  2263.000000  2018.000000    2.263000e+03    2263.000000  2.263000e+03
# mean      0.238179    52.273538    2.615991e+05     990.710561  2.625898e+05
# std       0.426064    11.869373    2.549906e+05    1602.839174  2.559822e+05
# min       0.000000    25.000000    1.339000e+03       0.000000  1.342000e+03
# 25%       0.000000    43.250000    2.103450e+04      57.000000  2.116250e+04
# 50%       0.000000    52.000000    1.539340e+05     316.000000  1.544890e+05
# 75%       0.000000    61.000000    4.858040e+05    1385.000000  4.872315e+05
# max       1.000000    86.000000    1.066824e+06   19367.000000  1.068569e+06
#
#        OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# count                            2263.000000
# mean                               15.811412
# std                                14.962861
# min                                 0.097941
# 25%                                 1.296518
# 50%                                10.510553
# 75%                                29.468185
# max                                51.951012
#
#        OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  TOTAL ELECTORS
# count                                2263.000000    2.263000e+03
# mean                                   23.190525    1.658016e+06
# std                                    21.564758    3.145187e+05
# min                                     1.000039    5.518900e+04
# 25%                                     1.899502    1.530014e+06
# 50%                                    16.221721    1.679030e+06
# 75%                                    42.590233    1.816857e+06
# max                                    74.411856    3.150313e+06

# %% [markdown]
# ## Getting some info about the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2263 entries, 0 to 2262
# Data columns (total 19 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   STATE                                     2263 non-null   object
#  1   CONSTITUENCY                              2263 non-null   object
#  2   NAME                                      2263 non-null   object
#  3   WINNER                                    2263 non-null   int64
#  4   PARTY                                     2263 non-null   object
#  5   SYMBOL                                    2018 non-null   object
#  6   GENDER                                    2018 non-null   object
#  7   CRIMINAL
# CASES                            2018 non-null   object
#  8   AGE                                       2018 non-null   float64
#  9   CATEGORY                                  2018 non-null   object
#  10  EDUCATION                                 2018 non-null   object
#  11  ASSETS                                    2018 non-null   object
#  12  LIABILITIES                               2018 non-null   object
#  13  GENERAL
# VOTES                             2263 non-null   int64
#  14  POSTAL
# VOTES                              2263 non-null   int64
#  15  TOTAL
# VOTES                               2263 non-null   int64
#  16  OVER TOTAL ELECTORS
# IN CONSTITUENCY      2263 non-null   float64
#  17  OVER TOTAL VOTES POLLED
# IN CONSTITUENCY  2263 non-null   float64
#  18  TOTAL ELECTORS                            2263 non-null   int64
# dtypes: float64(3), int64(5), object(11)
# memory usage: 336.0+ KB

# %% [markdown]
# ## Renaming specific columns

# %%
df.rename(columns={"CRIMINAL\nCASES": "CRIMINAL CASES", "GENERAL\nVOTES": "GENERAL VOTES", "POSTAL\nVOTES": "POSTAL VOTES","TOTAL\nVOTES": "TOTAL VOTES","OVER TOTAL ELECTORS \nIN CONSTITUENCY": "OVER TOTAL ELECTORS IN CONSTITUENCY","OVER TOTAL VOTES POLLED \nIN CONSTITUENCY": "OVER TOTAL VOTES POLLED IN CONSTITUENCY"}, inplace=True)
df.head()
# Out:
#            STATE CONSTITUENCY                   NAME  WINNER PARTY SYMBOL  \
# 0      Telangana     ADILABAD         SOYAM BAPU RAO       1   BJP  Lotus
# 1      Telangana     ADILABAD           Godam Nagesh       0   TRS    Car
# 2      Telangana     ADILABAD          RATHOD RAMESH       0   INC   Hand
# 3      Telangana     ADILABAD                   NOTA       0  NOTA    NaN
# 4  Uttar Pradesh         AGRA  Satyapal Singh Baghel       1   BJP  Lotus
#
#   GENDER CRIMINAL CASES   AGE CATEGORY      EDUCATION  \
# 0   MALE             52  52.0       ST      12th Pass
# 1   MALE              0  54.0       ST  Post Graduate
# 2   MALE              3  52.0       ST      12th Pass
# 3    NaN            NaN   NaN      NaN            NaN
# 4   MALE              5  58.0       SC      Doctorate
#
#                         ASSETS                  LIABILITIES  GENERAL VOTES  \
# 0    Rs 30,99,414\n ~ 30 Lacs+      Rs 2,31,450\n ~ 2 Lacs+         376892
# 1  Rs 1,84,77,888\n ~ 1 Crore+      Rs 8,47,000\n ~ 8 Lacs+         318665
# 2  Rs 3,64,91,000\n ~ 3 Crore+  Rs 1,53,00,000\n ~ 1 Crore+         314057
# 3                          NaN                          NaN          13030
# 4  Rs 7,42,74,036\n ~ 7 Crore+    Rs 86,06,522\n ~ 86 Lacs+         644459
#
#    POSTAL VOTES  TOTAL VOTES  OVER TOTAL ELECTORS IN CONSTITUENCY  \
# 0           482       377374                            25.330684
# 1           149       318814                            21.399929
# 2           181       314238                            21.092771
# 3             6        13036                             0.875023
# 4          2416       646875                            33.383823
#
#    OVER TOTAL VOTES POLLED IN CONSTITUENCY  TOTAL ELECTORS
# 0                                35.468248         1489790
# 1                                29.964370         1489790
# 2                                29.534285         1489790
# 3                                 1.225214         1489790
# 4                                56.464615         1937690

# %% [markdown]
# ## Checking for datatypes of columns

# %%
df.dtypes
# Out:
# STATE                                       object
# CONSTITUENCY                                object
# NAME                                        object
# WINNER                                       int64
# PARTY                                       object
# SYMBOL                                      object
# GENDER                                      object
# CRIMINAL CASES                              object
# AGE                                        float64
# CATEGORY                                    object
# EDUCATION                                   object
# ASSETS                                      object
# LIABILITIES                                 object
# GENERAL VOTES                                int64
# POSTAL VOTES                                 int64
# TOTAL VOTES                                  int64
# OVER TOTAL ELECTORS IN CONSTITUENCY        float64
# OVER TOTAL VOTES POLLED IN CONSTITUENCY    float64
# TOTAL ELECTORS                               int64
# dtype: object

# %% [markdown]
# ## Cleaning the Dataset !

# %% [markdown]
# ![OIP.jfif](attachment:OIP.jfif)

# %% [markdown]
# ## Finding which column has null values

# %%
df.isna().sum()
# Out:
# STATE                                        0
# CONSTITUENCY                                 0
# NAME                                         0
# WINNER                                       0
# PARTY                                        0
# SYMBOL                                     245
# GENDER                                     245
# CRIMINAL CASES                             245
# AGE                                        245
# CATEGORY                                   245
# EDUCATION                                  245
# ASSETS                                     245
# LIABILITIES                                245
# GENERAL VOTES                                0
# POSTAL VOTES                                 0
# TOTAL VOTES                                  0
# OVER TOTAL ELECTORS IN CONSTITUENCY          0
# OVER TOTAL VOTES POLLED IN CONSTITUENCY      0
# TOTAL ELECTORS                               0
# dtype: int64

# %% [markdown]
# ## Finding the total number of null values present

# %%
df.isna().sum().sum()
# Out:
# 1960

# %%
df.EDUCATION.replace({'Post Graduate/n':'Post Graduate'},inplace=True)
df.EDUCATION.unique()
# Out:
# array(['12th Pass', 'Post Graduate', nan, 'Doctorate', 'Graduate',
#        'Others', '10th Pass', '8th Pass', 'Graduate Professional',
#        'Literate', 'Illiterate', '5th Pass', 'Not Available',
#        'Post Graduate\n'], dtype=object)

# %% [markdown]
# ## Mapping the column GENDER to fill NaN values

# %%
df["GENDER_map"]=df.GENDER.map({'MALE':0,'FEMALE':1})
df
# Out:
#               STATE     CONSTITUENCY                   NAME  WINNER PARTY  \
# 0         Telangana         ADILABAD         SOYAM BAPU RAO       1   BJP
# 1         Telangana         ADILABAD           Godam Nagesh       0   TRS
# 2         Telangana         ADILABAD          RATHOD RAMESH       0   INC
# 3         Telangana         ADILABAD                   NOTA       0  NOTA
# 4     Uttar Pradesh             AGRA  Satyapal Singh Baghel       1   BJP
# ...             ...              ...                    ...     ...   ...
# 2258    Maharashtra  YAVATMAL-WASHIM     Anil Jayram Rathod       0   IND
# 2259      Telangana        ZAHIRABAD              B.B.PATIL       1   TRS
# 2260      Telangana        ZAHIRABAD        MADAN MOHAN RAO       0   INC
# 2261      Telangana        ZAHIRABAD     BANALA LAXMA REDDY       0   BJP
# 2262      Telangana        ZAHIRABAD                   NOTA       0  NOTA
#
#      SYMBOL GENDER CRIMINAL CASES   AGE CATEGORY      EDUCATION  \
# 0     Lotus   MALE             52  52.0       ST      12th Pass
# 1       Car   MALE              0  54.0       ST  Post Graduate
# 2      Hand   MALE              3  52.0       ST      12th Pass
# 3       NaN    NaN            NaN   NaN      NaN            NaN
# 4     Lotus   MALE              5  58.0       SC      Doctorate
# ...     ...    ...            ...   ...      ...            ...
# 2258   SHIP   MALE              0  43.0  GENERAL  Post Graduate
# 2259    Car   MALE             18  63.0  GENERAL       Graduate
# 2260   Hand   MALE              0  49.0  GENERAL  Post Graduate
# 2261  Lotus   MALE              3  47.0  GENERAL      12th Pass
# 2262    NaN    NaN            NaN   NaN      NaN            NaN
#
#                                 ASSETS                  LIABILITIES  \
# 0            Rs 30,99,414\n ~ 30 Lacs+      Rs 2,31,450\n ~ 2 Lacs+
# 1          Rs 1,84,77,888\n ~ 1 Crore+      Rs 8,47,000\n ~ 8 Lacs+
# 2          Rs 3,64,91,000\n ~ 3 Crore+  Rs 1,53,00,000\n ~ 1 Crore+
# 3                                  NaN                          NaN
# 4          Rs 7,42,74,036\n ~ 7 Crore+    Rs 86,06,522\n ~ 86 Lacs+
# ...                                ...                          ...
# 2258         Rs 48,90,000\n ~ 48 Lacs+    Rs 10,20,000\n ~ 10 Lacs+
# 2259  Rs 1,28,78,51,556\n ~ 128 Crore+  Rs 1,15,35,000\n ~ 1 Crore+
# 2260     Rs 90,36,63,001\n ~ 90 Crore+                     Rs 0\n ~
# 2261       Rs 5,85,77,327\n ~ 5 Crore+    Rs 52,50,000\n ~ 52 Lacs+
# 2262                               NaN                          NaN
#
#       GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 0            376892           482       377374
# 1            318665           149       318814
# 2            314057           181       314238
# 3             13030             6        13036
# 4            644459          2416       646875
# ...             ...           ...          ...
# 2258          14661            25        14686
# 2259         434066           178       434244
# 2260         427900           115       428015
# 2261         138731           216       138947
# 2262          11138             2        11140
#
#       OVER TOTAL ELECTORS IN CONSTITUENCY  \
# 0                               25.330684
# 1                               21.399929
# 2                               21.092771
# 3                                0.875023
# 4                               33.383823
# ...                                   ...
# 2258                             0.766419
# 2259                            28.975369
# 2260                            28.559732
# 2261                             9.271379
# 2262                             0.743328
#
#       OVER TOTAL VOTES POLLED IN CONSTITUENCY  TOTAL ELECTORS  GENDER_map
# 0                                   35.468248         1489790         0.0
# 1                                   29.964370         1489790         0.0
# 2                                   29.534285         1489790         0.0
# 3                                    1.225214         1489790         NaN
# 4                                   56.464615         1937690         0.0
# ...                                       ...             ...         ...
# 2258                                 1.250060         1916185         0.0
# 2259                                41.574183         1498666         0.0
# 2260                                40.977823         1498666         0.0
# 2261                                13.302678         1498666         0.0
# 2262                                 1.066535         1498666         NaN
#
# [2263 rows x 20 columns]

# %% [markdown]
# ## Dataframe consisting of GENDER_map and columns with float and int as dtypes

# %%
df2=df[["GENDER_map","WINNER","AGE","GENERAL VOTES","POSTAL VOTES","TOTAL VOTES","OVER TOTAL ELECTORS IN CONSTITUENCY","OVER TOTAL VOTES POLLED IN CONSTITUENCY","TOTAL ELECTORS"]]
df2
# Out:
#       GENDER_map  WINNER   AGE  GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 0            0.0       1  52.0         376892           482       377374
# 1            0.0       0  54.0         318665           149       318814
# 2            0.0       0  52.0         314057           181       314238
# 3            NaN       0   NaN          13030             6        13036
# 4            0.0       1  58.0         644459          2416       646875
# ...          ...     ...   ...            ...           ...          ...
# 2258         0.0       0  43.0          14661            25        14686
# 2259         0.0       1  63.0         434066           178       434244
# 2260         0.0       0  49.0         427900           115       428015
# 2261         0.0       0  47.0         138731           216       138947
# 2262         NaN       0   NaN          11138             2        11140
#
#       OVER TOTAL ELECTORS IN CONSTITUENCY  \
# 0                               25.330684
# 1                               21.399929
# 2                               21.092771
# 3                                0.875023
# 4                               33.383823
# ...                                   ...
# 2258                             0.766419
# 2259                            28.975369
# 2260                            28.559732
# 2261                             9.271379
# 2262                             0.743328
#
#       OVER TOTAL VOTES POLLED IN CONSTITUENCY  TOTAL ELECTORS
# 0                                   35.468248         1489790
# 1                                   29.964370         1489790
# 2                                   29.534285         1489790
# 3                                    1.225214         1489790
# 4                                   56.464615         1937690
# ...                                       ...             ...
# 2258                                 1.250060         1916185
# 2259                                41.574183         1498666
# 2260                                40.977823         1498666
# 2261                                13.302678         1498666
# 2262                                 1.066535         1498666
#
# [2263 rows x 9 columns]

# %%
#USING fillna method , filling null values with mean

# %%
#df2.mean()
#df2.fillna(df2.mean)

# %% [markdown]
# ## Using KNN Imputer to replace the NaN values

# %% [markdown]
# WE WILL GET VALUES IN ARRAY FORMAT, WE'LL HAVE TO CONVERT IT INTO DATAFRAME

# %%
imputer=KNNImputer(n_neighbors=1)
After_imputation=imputer.fit_transform(df2)
After_imputation
# Out:
# array([[0.00000000e+00, 1.00000000e+00, 5.20000000e+01, ...,
#         2.53306842e+01, 3.54682479e+01, 1.48979000e+06],
#        [0.00000000e+00, 0.00000000e+00, 5.40000000e+01, ...,
#         2.13999288e+01, 2.99643695e+01, 1.48979000e+06],
#        [0.00000000e+00, 0.00000000e+00, 5.20000000e+01, ...,
#         2.10927715e+01, 2.95342851e+01, 1.48979000e+06],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 4.90000000e+01, ...,
#         2.85597325e+01, 4.09778230e+01, 1.49866600e+06],
#        [0.00000000e+00, 0.00000000e+00, 4.70000000e+01, ...,
#         9.27137868e+00, 1.33026776e+01, 1.49866600e+06],
#        [0.00000000e+00, 0.00000000e+00, 5.50000000e+01, ...,
#         7.43327733e-01, 1.06653493e+00, 1.49866600e+06]])

# %%
col=df2.columns
col
# Out:
# Index(['GENDER_map', 'WINNER', 'AGE', 'GENERAL VOTES', 'POSTAL VOTES',
#        'TOTAL VOTES', 'OVER TOTAL ELECTORS IN CONSTITUENCY',
#        'OVER TOTAL VOTES POLLED IN CONSTITUENCY', 'TOTAL ELECTORS'],
#       dtype='object')

# %% [markdown]
# ## df3 consisting of 0 NaN values

# %%
df3=pd.DataFrame(After_imputation,columns=col)
df3
# Out:
#       GENDER_map  WINNER   AGE  GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 0            0.0     1.0  52.0       376892.0         482.0     377374.0
# 1            0.0     0.0  54.0       318665.0         149.0     318814.0
# 2            0.0     0.0  52.0       314057.0         181.0     314238.0
# 3            1.0     0.0  47.0        13030.0           6.0      13036.0
# 4            0.0     1.0  58.0       644459.0        2416.0     646875.0
# ...          ...     ...   ...            ...           ...          ...
# 2258         0.0     0.0  43.0        14661.0          25.0      14686.0
# 2259         0.0     1.0  63.0       434066.0         178.0     434244.0
# 2260         0.0     0.0  49.0       427900.0         115.0     428015.0
# 2261         0.0     0.0  47.0       138731.0         216.0     138947.0
# 2262         0.0     0.0  55.0        11138.0           2.0      11140.0
#
#       OVER TOTAL ELECTORS IN CONSTITUENCY  \
# 0                               25.330684
# 1                               21.399929
# 2                               21.092771
# 3                                0.875023
# 4                               33.383823
# ...                                   ...
# 2258                             0.766419
# 2259                            28.975369
# 2260                            28.559732
# 2261                             9.271379
# 2262                             0.743328
#
#       OVER TOTAL VOTES POLLED IN CONSTITUENCY  TOTAL ELECTORS
# 0                                   35.468248       1489790.0
# 1                                   29.964370       1489790.0
# 2                                   29.534285       1489790.0
# 3                                    1.225214       1489790.0
# 4                                   56.464615       1937690.0
# ...                                       ...             ...
# 2258                                 1.250060       1916185.0
# 2259                                41.574183       1498666.0
# 2260                                40.977823       1498666.0
# 2261                                13.302678       1498666.0
# 2262                                 1.066535       1498666.0
#
# [2263 rows x 9 columns]

# %%
df3.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Again mapping Gender column to get it in proper form.

# %%
df3["GENDER"]=df3.GENDER_map.map({0:"MALE",1:"FEMALE"})
df3
# Out:
#       GENDER_map  WINNER   AGE  GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 0            0.0     1.0  52.0       376892.0         482.0     377374.0
# 1            0.0     0.0  54.0       318665.0         149.0     318814.0
# 2            0.0     0.0  52.0       314057.0         181.0     314238.0
# 3            1.0     0.0  47.0        13030.0           6.0      13036.0
# 4            0.0     1.0  58.0       644459.0        2416.0     646875.0
# ...          ...     ...   ...            ...           ...          ...
# 2258         0.0     0.0  43.0        14661.0          25.0      14686.0
# 2259         0.0     1.0  63.0       434066.0         178.0     434244.0
# 2260         0.0     0.0  49.0       427900.0         115.0     428015.0
# 2261         0.0     0.0  47.0       138731.0         216.0     138947.0
# 2262         0.0     0.0  55.0        11138.0           2.0      11140.0
#
#       OVER TOTAL ELECTORS IN CONSTITUENCY  \
# 0                               25.330684
# 1                               21.399929
# 2                               21.092771
# 3                                0.875023
# 4                               33.383823
# ...                                   ...
# 2258                             0.766419
# 2259                            28.975369
# 2260                            28.559732
# 2261                             9.271379
# 2262                             0.743328
#
#       OVER TOTAL VOTES POLLED IN CONSTITUENCY  TOTAL ELECTORS  GENDER
# 0                                   35.468248       1489790.0    MALE
# 1                                   29.964370       1489790.0    MALE
# 2                                   29.534285       1489790.0    MALE
# 3                                    1.225214       1489790.0  FEMALE
# 4                                   56.464615       1937690.0    MALE
# ...                                       ...             ...     ...
# 2258                                 1.250060       1916185.0    MALE
# 2259                                41.574183       1498666.0    MALE
# 2260                                40.977823       1498666.0    MALE
# 2261                                13.302678       1498666.0    MALE
# 2262                                 1.066535       1498666.0    MALE
#
# [2263 rows x 10 columns]

# %% [markdown]
# ## Dropping GENDER_map column which is not required now.

# %%
df3.drop("GENDER_map",axis=1,inplace=True)

# %%
df3
# Out:
#       WINNER   AGE  GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 0        1.0  52.0       376892.0         482.0     377374.0
# 1        0.0  54.0       318665.0         149.0     318814.0
# 2        0.0  52.0       314057.0         181.0     314238.0
# 3        0.0  47.0        13030.0           6.0      13036.0
# 4        1.0  58.0       644459.0        2416.0     646875.0
# ...      ...   ...            ...           ...          ...
# 2258     0.0  43.0        14661.0          25.0      14686.0
# 2259     1.0  63.0       434066.0         178.0     434244.0
# 2260     0.0  49.0       427900.0         115.0     428015.0
# 2261     0.0  47.0       138731.0         216.0     138947.0
# 2262     0.0  55.0        11138.0           2.0      11140.0
#
#       OVER TOTAL ELECTORS IN CONSTITUENCY  \
# 0                               25.330684
# 1                               21.399929
# 2                               21.092771
# 3                                0.875023
# 4                               33.383823
# ...                                   ...
# 2258                             0.766419
# 2259                            28.975369
# 2260                            28.559732
# 2261                             9.271379
# 2262                             0.743328
#
#       OVER TOTAL VOTES POLLED IN CONSTITUENCY  TOTAL ELECTORS  GENDER
# 0                                   35.468248       1489790.0    MALE
# 1                                   29.964370       1489790.0    MALE
# 2                                   29.534285       1489790.0    MALE
# 3                                    1.225214       1489790.0  FEMALE
# 4                                   56.464615       1937690.0    MALE
# ...                                       ...             ...     ...
# 2258                                 1.250060       1916185.0    MALE
# 2259                                41.574183       1498666.0    MALE
# 2260                                40.977823       1498666.0    MALE
# 2261                                13.302678       1498666.0    MALE
# 2262                                 1.066535       1498666.0    MALE
#
# [2263 rows x 9 columns]

# %% [markdown]
# ## Creating a dataframe consisting only "object" type columns

# %%
df_obj=df.select_dtypes(include=["object"])
df_obj
# Out:
#               STATE     CONSTITUENCY                   NAME PARTY SYMBOL  \
# 0         Telangana         ADILABAD         SOYAM BAPU RAO   BJP  Lotus
# 1         Telangana         ADILABAD           Godam Nagesh   TRS    Car
# 2         Telangana         ADILABAD          RATHOD RAMESH   INC   Hand
# 3         Telangana         ADILABAD                   NOTA  NOTA    NaN
# 4     Uttar Pradesh             AGRA  Satyapal Singh Baghel   BJP  Lotus
# ...             ...              ...                    ...   ...    ...
# 2258    Maharashtra  YAVATMAL-WASHIM     Anil Jayram Rathod   IND   SHIP
# 2259      Telangana        ZAHIRABAD              B.B.PATIL   TRS    Car
# 2260      Telangana        ZAHIRABAD        MADAN MOHAN RAO   INC   Hand
# 2261      Telangana        ZAHIRABAD     BANALA LAXMA REDDY   BJP  Lotus
# 2262      Telangana        ZAHIRABAD                   NOTA  NOTA    NaN
#
#      GENDER CRIMINAL CASES CATEGORY      EDUCATION  \
# 0      MALE             52       ST      12th Pass
# 1      MALE              0       ST  Post Graduate
# 2      MALE              3       ST      12th Pass
# 3       NaN            NaN      NaN            NaN
# 4      MALE              5       SC      Doctorate
# ...     ...            ...      ...            ...
# 2258   MALE              0  GENERAL  Post Graduate
# 2259   MALE             18  GENERAL       Graduate
# 2260   MALE              0  GENERAL  Post Graduate
# 2261   MALE              3  GENERAL      12th Pass
# 2262    NaN            NaN      NaN            NaN
#
#                                 ASSETS                  LIABILITIES
# 0            Rs 30,99,414\n ~ 30 Lacs+      Rs 2,31,450\n ~ 2 Lacs+
# 1          Rs 1,84,77,888\n ~ 1 Crore+      Rs 8,47,000\n ~ 8 Lacs+
# 2          Rs 3,64,91,000\n ~ 3 Crore+  Rs 1,53,00,000\n ~ 1 Crore+
# 3                                  NaN                          NaN
# 4          Rs 7,42,74,036\n ~ 7 Crore+    Rs 86,06,522\n ~ 86 Lacs+
# ...                                ...                          ...
# 2258         Rs 48,90,000\n ~ 48 Lacs+    Rs 10,20,000\n ~ 10 Lacs+
# 2259  Rs 1,28,78,51,556\n ~ 128 Crore+  Rs 1,15,35,000\n ~ 1 Crore+
# 2260     Rs 90,36,63,001\n ~ 90 Crore+                     Rs 0\n ~
# 2261       Rs 5,85,77,327\n ~ 5 Crore+    Rs 52,50,000\n ~ 52 Lacs+
# 2262                               NaN                          NaN
#
# [2263 rows x 11 columns]

# %%
df_obj.drop("GENDER",axis=1,inplace=True)
# Out:
# C:\Users\nayye\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_obj
# Out:
#               STATE     CONSTITUENCY                   NAME PARTY SYMBOL  \
# 0         Telangana         ADILABAD         SOYAM BAPU RAO   BJP  Lotus
# 1         Telangana         ADILABAD           Godam Nagesh   TRS    Car
# 2         Telangana         ADILABAD          RATHOD RAMESH   INC   Hand
# 3         Telangana         ADILABAD                   NOTA  NOTA    NaN
# 4     Uttar Pradesh             AGRA  Satyapal Singh Baghel   BJP  Lotus
# ...             ...              ...                    ...   ...    ...
# 2258    Maharashtra  YAVATMAL-WASHIM     Anil Jayram Rathod   IND   SHIP
# 2259      Telangana        ZAHIRABAD              B.B.PATIL   TRS    Car
# 2260      Telangana        ZAHIRABAD        MADAN MOHAN RAO   INC   Hand
# 2261      Telangana        ZAHIRABAD     BANALA LAXMA REDDY   BJP  Lotus
# 2262      Telangana        ZAHIRABAD                   NOTA  NOTA    NaN
#
#      CRIMINAL CASES CATEGORY      EDUCATION                            ASSETS  \
# 0                52       ST      12th Pass         Rs 30,99,414\n ~ 30 Lacs+
# 1                 0       ST  Post Graduate       Rs 1,84,77,888\n ~ 1 Crore+
# 2                 3       ST      12th Pass       Rs 3,64,91,000\n ~ 3 Crore+
# 3               NaN      NaN            NaN                               NaN
# 4                 5       SC      Doctorate       Rs 7,42,74,036\n ~ 7 Crore+
# ...             ...      ...            ...                               ...
# 2258              0  GENERAL  Post Graduate         Rs 48,90,000\n ~ 48 Lacs+
# 2259             18  GENERAL       Graduate  Rs 1,28,78,51,556\n ~ 128 Crore+
# 2260              0  GENERAL  Post Graduate     Rs 90,36,63,001\n ~ 90 Crore+
# 2261              3  GENERAL      12th Pass       Rs 5,85,77,327\n ~ 5 Crore+
# 2262            NaN      NaN            NaN                               NaN
#
#                       LIABILITIES
# 0         Rs 2,31,450\n ~ 2 Lacs+
# 1         Rs 8,47,000\n ~ 8 Lacs+
# 2     Rs 1,53,00,000\n ~ 1 Crore+
# 3                             NaN
# 4       Rs 86,06,522\n ~ 86 Lacs+
# ...                           ...
# 2258    Rs 10,20,000\n ~ 10 Lacs+
# 2259  Rs 1,15,35,000\n ~ 1 Crore+
# 2260                     Rs 0\n ~
# 2261    Rs 52,50,000\n ~ 52 Lacs+
# 2262                          NaN
#
# [2263 rows x 10 columns]

# %% [markdown]
# ## Creating new_df by joining df_obj and df3 using pd.concat

# %%
new_df=pd.concat([df_obj,df3],axis=1)
new_df
# Out:
#               STATE     CONSTITUENCY                   NAME PARTY SYMBOL  \
# 0         Telangana         ADILABAD         SOYAM BAPU RAO   BJP  Lotus
# 1         Telangana         ADILABAD           Godam Nagesh   TRS    Car
# 2         Telangana         ADILABAD          RATHOD RAMESH   INC   Hand
# 3         Telangana         ADILABAD                   NOTA  NOTA    NaN
# 4     Uttar Pradesh             AGRA  Satyapal Singh Baghel   BJP  Lotus
# ...             ...              ...                    ...   ...    ...
# 2258    Maharashtra  YAVATMAL-WASHIM     Anil Jayram Rathod   IND   SHIP
# 2259      Telangana        ZAHIRABAD              B.B.PATIL   TRS    Car
# 2260      Telangana        ZAHIRABAD        MADAN MOHAN RAO   INC   Hand
# 2261      Telangana        ZAHIRABAD     BANALA LAXMA REDDY   BJP  Lotus
# 2262      Telangana        ZAHIRABAD                   NOTA  NOTA    NaN
#
#      CRIMINAL CASES CATEGORY      EDUCATION                            ASSETS  \
# 0                52       ST      12th Pass         Rs 30,99,414\n ~ 30 Lacs+
# 1                 0       ST  Post Graduate       Rs 1,84,77,888\n ~ 1 Crore+
# 2                 3       ST      12th Pass       Rs 3,64,91,000\n ~ 3 Crore+
# 3               NaN      NaN            NaN                               NaN
# 4                 5       SC      Doctorate       Rs 7,42,74,036\n ~ 7 Crore+
# ...             ...      ...            ...                               ...
# 2258              0  GENERAL  Post Graduate         Rs 48,90,000\n ~ 48 Lacs+
# 2259             18  GENERAL       Graduate  Rs 1,28,78,51,556\n ~ 128 Crore+
# 2260              0  GENERAL  Post Graduate     Rs 90,36,63,001\n ~ 90 Crore+
# 2261              3  GENERAL      12th Pass       Rs 5,85,77,327\n ~ 5 Crore+
# 2262            NaN      NaN            NaN                               NaN
#
#                       LIABILITIES  WINNER   AGE  GENERAL VOTES  POSTAL VOTES  \
# 0         Rs 2,31,450\n ~ 2 Lacs+     1.0  52.0       376892.0         482.0
# 1         Rs 8,47,000\n ~ 8 Lacs+     0.0  54.0       318665.0         149.0
# 2     Rs 1,53,00,000\n ~ 1 Crore+     0.0  52.0       314057.0         181.0
# 3                             NaN     0.0  47.0        13030.0           6.0
# 4       Rs 86,06,522\n ~ 86 Lacs+     1.0  58.0       644459.0        2416.0
# ...                           ...     ...   ...            ...           ...
# 2258    Rs 10,20,000\n ~ 10 Lacs+     0.0  43.0        14661.0          25.0
# 2259  Rs 1,15,35,000\n ~ 1 Crore+     1.0  63.0       434066.0         178.0
# 2260                     Rs 0\n ~     0.0  49.0       427900.0         115.0
# 2261    Rs 52,50,000\n ~ 52 Lacs+     0.0  47.0       138731.0         216.0
# 2262                          NaN     0.0  55.0        11138.0           2.0
#
#       TOTAL VOTES  OVER TOTAL ELECTORS IN CONSTITUENCY  \
# 0        377374.0                            25.330684
# 1        318814.0                            21.399929
# 2        314238.0                            21.092771
# 3         13036.0                             0.875023
# 4        646875.0                            33.383823
# ...           ...                                  ...
# 2258      14686.0                             0.766419
# 2259     434244.0                            28.975369
# 2260     428015.0                            28.559732
# 2261     138947.0                             9.271379
# 2262      11140.0                             0.743328
#
#       OVER TOTAL VOTES POLLED IN CONSTITUENCY  TOTAL ELECTORS  GENDER
# 0                                   35.468248       1489790.0    MALE
# 1                                   29.964370       1489790.0    MALE
# 2                                   29.534285       1489790.0    MALE
# 3                                    1.225214       1489790.0  FEMALE
# 4                                   56.464615       1937690.0    MALE
# ...                                       ...             ...     ...
# 2258                                 1.250060       1916185.0    MALE
# 2259                                41.574183       1498666.0    MALE
# 2260                                40.977823       1498666.0    MALE
# 2261                                13.302678       1498666.0    MALE
# 2262                                 1.066535       1498666.0    MALE
#
# [2263 rows x 19 columns]

# %% [markdown]
# ## Removing all the records where PARTY is "NOTA".

# %%
new_df=new_df[new_df['PARTY']!='NOTA']
new_df
# Out:
#               STATE     CONSTITUENCY                    NAME  PARTY    SYMBOL  \
# 0         Telangana         ADILABAD          SOYAM BAPU RAO    BJP     Lotus
# 1         Telangana         ADILABAD            Godam Nagesh    TRS       Car
# 2         Telangana         ADILABAD           RATHOD RAMESH    INC      Hand
# 4     Uttar Pradesh             AGRA   Satyapal Singh Baghel    BJP     Lotus
# 5     Uttar Pradesh             AGRA        Manoj Kumar Soni    BSP  Elephant
# ...             ...              ...                     ...    ...       ...
# 2257    Maharashtra  YAVATMAL-WASHIM  Vaishali Sudhakar Yede  PHJSP   Whistle
# 2258    Maharashtra  YAVATMAL-WASHIM      Anil Jayram Rathod    IND      SHIP
# 2259      Telangana        ZAHIRABAD               B.B.PATIL    TRS       Car
# 2260      Telangana        ZAHIRABAD         MADAN MOHAN RAO    INC      Hand
# 2261      Telangana        ZAHIRABAD      BANALA LAXMA REDDY    BJP     Lotus
#
#      CRIMINAL CASES CATEGORY      EDUCATION                            ASSETS  \
# 0                52       ST      12th Pass         Rs 30,99,414\n ~ 30 Lacs+
# 1                 0       ST  Post Graduate       Rs 1,84,77,888\n ~ 1 Crore+
# 2                 3       ST      12th Pass       Rs 3,64,91,000\n ~ 3 Crore+
# 4                 5       SC      Doctorate       Rs 7,42,74,036\n ~ 7 Crore+
# 5                 0       SC  Post Graduate     Rs 13,37,84,385\n ~ 13 Crore+
# ...             ...      ...            ...                               ...
# 2257              0  GENERAL      10th Pass         Rs 11,68,500\n ~ 11 Lacs+
# 2258              0  GENERAL  Post Graduate         Rs 48,90,000\n ~ 48 Lacs+
# 2259             18  GENERAL       Graduate  Rs 1,28,78,51,556\n ~ 128 Crore+
# 2260              0  GENERAL  Post Graduate     Rs 90,36,63,001\n ~ 90 Crore+
# 2261              3  GENERAL      12th Pass       Rs 5,85,77,327\n ~ 5 Crore+
#
#                       LIABILITIES  WINNER   AGE  GENERAL VOTES  POSTAL VOTES  \
# 0         Rs 2,31,450\n ~ 2 Lacs+     1.0  52.0       376892.0         482.0
# 1         Rs 8,47,000\n ~ 8 Lacs+     0.0  54.0       318665.0         149.0
# 2     Rs 1,53,00,000\n ~ 1 Crore+     0.0  52.0       314057.0         181.0
# 4       Rs 86,06,522\n ~ 86 Lacs+     1.0  58.0       644459.0        2416.0
# 5     Rs 2,22,51,891\n ~ 2 Crore+     0.0  47.0       434199.0        1130.0
# ...                           ...     ...   ...            ...           ...
# 2257         Rs 9,000\n ~ 9 Thou+     0.0  28.0        20563.0          57.0
# 2258    Rs 10,20,000\n ~ 10 Lacs+     0.0  43.0        14661.0          25.0
# 2259  Rs 1,15,35,000\n ~ 1 Crore+     1.0  63.0       434066.0         178.0
# 2260                     Rs 0\n ~     0.0  49.0       427900.0         115.0
# 2261    Rs 52,50,000\n ~ 52 Lacs+     0.0  47.0       138731.0         216.0
#
#       TOTAL VOTES  OVER TOTAL ELECTORS IN CONSTITUENCY  \
# 0        377374.0                            25.330684
# 1        318814.0                            21.399929
# 2        314238.0                            21.092771
# 4        646875.0                            33.383823
# 5        435329.0                            22.466390
# ...           ...                                  ...
# 2257      20620.0                             1.076097
# 2258      14686.0                             0.766419
# 2259     434244.0                            28.975369
# 2260     428015.0                            28.559732
# 2261     138947.0                             9.271379
#
#       OVER TOTAL VOTES POLLED IN CONSTITUENCY  TOTAL ELECTORS  GENDER
# 0                                   35.468248       1489790.0    MALE
# 1                                   29.964370       1489790.0    MALE
# 2                                   29.534285       1489790.0    MALE
# 4                                   56.464615       1937690.0    MALE
# 5                                   37.999125       1937690.0    MALE
# ...                                       ...             ...     ...
# 2257                                 1.755157       1916185.0  FEMALE
# 2258                                 1.250060       1916185.0    MALE
# 2259                                41.574183       1498666.0    MALE
# 2260                                40.977823       1498666.0    MALE
# 2261                                13.302678       1498666.0    MALE
#
# [2018 rows x 19 columns]

# %% [markdown]
# ## defining a function to change the format of values in columns ASSETS and LIABILITIES.

# %%
def value_cleaner(x):
    try:
        str_temp = (x.split('Rs')[1].split('\n')[0].strip())
        str_temp_2 = ''
        for i in str_temp.split(","):
            str_temp_2 = str_temp_2+i
        return str_temp_2
    except:
        x = 0
        return x
new_df['ASSETS'] = new_df['ASSETS'].apply((value_cleaner))
new_df['LIABILITIES'] = new_df['LIABILITIES'].apply((value_cleaner))
new_df.head()
# Out:
# <ipython-input-25-6d6ff7bca935>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['ASSETS'] = new_df['ASSETS'].apply((value_cleaner))
# <ipython-input-25-6d6ff7bca935>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['LIABILITIES'] = new_df['LIABILITIES'].apply((value_cleaner))
#            STATE CONSTITUENCY                   NAME PARTY    SYMBOL  \
# 0      Telangana     ADILABAD         SOYAM BAPU RAO   BJP     Lotus
# 1      Telangana     ADILABAD           Godam Nagesh   TRS       Car
# 2      Telangana     ADILABAD          RATHOD RAMESH   INC      Hand
# 4  Uttar Pradesh         AGRA  Satyapal Singh Baghel   BJP     Lotus
# 5  Uttar Pradesh         AGRA       Manoj Kumar Soni   BSP  Elephant
#
#   CRIMINAL CASES CATEGORY      EDUCATION     ASSETS LIABILITIES  WINNER   AGE  \
# 0             52       ST      12th Pass    3099414      231450     1.0  52.0
# 1              0       ST  Post Graduate   18477888      847000     0.0  54.0
# 2              3       ST      12th Pass   36491000    15300000     0.0  52.0
# 4              5       SC      Doctorate   74274036     8606522     1.0  58.0
# 5              0       SC  Post Graduate  133784385    22251891     0.0  47.0
#
#    GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 0       376892.0         482.0     377374.0
# 1       318665.0         149.0     318814.0
# 2       314057.0         181.0     314238.0
# 4       644459.0        2416.0     646875.0
# 5       434199.0        1130.0     435329.0
#
#    OVER TOTAL ELECTORS IN CONSTITUENCY  \
# 0                            25.330684
# 1                            21.399929
# 2                            21.092771
# 4                            33.383823
# 5                            22.466390
#
#    OVER TOTAL VOTES POLLED IN CONSTITUENCY  TOTAL ELECTORS GENDER
# 0                                35.468248       1489790.0   MALE
# 1                                29.964370       1489790.0   MALE
# 2                                29.534285       1489790.0   MALE
# 4                                56.464615       1937690.0   MALE
# 5                                37.999125       1937690.0   MALE

# %% [markdown]
# ## Creating a dataframe for "NOTA" records

# %%
nota_df=df[df["PARTY"]=="NOTA"]
nota_df
# Out:
#                STATE    CONSTITUENCY  NAME  WINNER PARTY SYMBOL GENDER  \
# 3          Telangana        ADILABAD  NOTA       0  NOTA    NaN    NaN
# 14           Gujarat  AHMEDABAD WEST  NOTA       0  NOTA    NaN    NaN
# 39       West Bengal     ALIPURDUARS  NOTA       0  NOTA    NaN    NaN
# 46       Uttarakhand          ALMORA  NOTA       0  NOTA    NaN    NaN
# 54    Andhra Pradesh      AMALAPURAM  NOTA       0  NOTA    NaN    NaN
# ...              ...             ...   ...     ...   ...    ...    ...
# 2225      Tamil Nadu    VIRUDHUNAGAR  NOTA       0  NOTA    NaN    NaN
# 2230  Andhra Pradesh   VISAKHAPATNAM  NOTA       0  NOTA    NaN    NaN
# 2235  Andhra Pradesh    VIZIANAGARAM  NOTA       0  NOTA    NaN    NaN
# 2241       Telangana        WARANGAL  NOTA       0  NOTA    NaN    NaN
# 2262       Telangana       ZAHIRABAD  NOTA       0  NOTA    NaN    NaN
#
#      CRIMINAL CASES  AGE CATEGORY EDUCATION ASSETS LIABILITIES  GENERAL VOTES  \
# 3               NaN  NaN      NaN       NaN    NaN         NaN          13030
# 14              NaN  NaN      NaN       NaN    NaN         NaN          14580
# 39              NaN  NaN      NaN       NaN    NaN         NaN          21147
# 46              NaN  NaN      NaN       NaN    NaN         NaN          15311
# 54              NaN  NaN      NaN       NaN    NaN         NaN          16427
# ...             ...  ...      ...       ...    ...         ...            ...
# 2225            NaN  NaN      NaN       NaN    NaN         NaN          17087
# 2230            NaN  NaN      NaN       NaN    NaN         NaN          16626
# 2235            NaN  NaN      NaN       NaN    NaN         NaN          29468
# 2241            NaN  NaN      NaN       NaN    NaN         NaN          18764
# 2262            NaN  NaN      NaN       NaN    NaN         NaN          11138
#
#       POSTAL VOTES  TOTAL VOTES  OVER TOTAL ELECTORS IN CONSTITUENCY  \
# 3                6        13036                             0.875023
# 14             139        14719                             0.895688
# 39              28        21175                             1.284592
# 46             194        15505                             1.158985
# 54              41        16468                             1.128288
# ...            ...          ...                                  ...
# 2225           205        17292                             1.165028
# 2230            20        16646                             0.909966
# 2235            33        29501                             1.961529
# 2241            37        18801                             1.127990
# 2262             2        11140                             0.743328
#
#       OVER TOTAL VOTES POLLED IN CONSTITUENCY  TOTAL ELECTORS  GENDER_map
# 3                                    1.225214         1489790         NaN
# 14                                   1.473030         1643317         NaN
# 39                                   1.533114         1648383         NaN
# 46                                   2.215611         1337808         NaN
# 54                                   1.333044         1459556         NaN
# ...                                       ...             ...         ...
# 2225                                 1.607174         1484256         NaN
# 2230                                 1.342505         1829300         NaN
# 2235                                 2.413302         1503980         NaN
# 2241                                 1.770886         1666770         NaN
# 2262                                 1.066535         1498666         NaN
#
# [245 rows x 20 columns]

# %%
new_df.shape
# Out:
# (2018, 19)

# %% [markdown]
# ## Converting the clean dataframe into csv file.

# %%
new_df.to_csv("Dataset_for_EDA.csv")

# %% [markdown]
# ## Converting the dataset of 'NOTA' into csv file.

# %%
nota_df.to_csv("Nota_dataset_for_EDA.csv")

# %%
new_df
# Out:
#               STATE     CONSTITUENCY                    NAME  PARTY    SYMBOL  \
# 0         Telangana         ADILABAD          SOYAM BAPU RAO    BJP     Lotus
# 1         Telangana         ADILABAD            Godam Nagesh    TRS       Car
# 2         Telangana         ADILABAD           RATHOD RAMESH    INC      Hand
# 4     Uttar Pradesh             AGRA   Satyapal Singh Baghel    BJP     Lotus
# 5     Uttar Pradesh             AGRA        Manoj Kumar Soni    BSP  Elephant
# ...             ...              ...                     ...    ...       ...
# 2257    Maharashtra  YAVATMAL-WASHIM  Vaishali Sudhakar Yede  PHJSP   Whistle
# 2258    Maharashtra  YAVATMAL-WASHIM      Anil Jayram Rathod    IND      SHIP
# 2259      Telangana        ZAHIRABAD               B.B.PATIL    TRS       Car
# 2260      Telangana        ZAHIRABAD         MADAN MOHAN RAO    INC      Hand
# 2261      Telangana        ZAHIRABAD      BANALA LAXMA REDDY    BJP     Lotus
#
#      CRIMINAL CASES CATEGORY      EDUCATION      ASSETS LIABILITIES  WINNER  \
# 0                52       ST      12th Pass     3099414      231450     1.0
# 1                 0       ST  Post Graduate    18477888      847000     0.0
# 2                 3       ST      12th Pass    36491000    15300000     0.0
# 4                 5       SC      Doctorate    74274036     8606522     1.0
# 5                 0       SC  Post Graduate   133784385    22251891     0.0
# ...             ...      ...            ...         ...         ...     ...
# 2257              0  GENERAL      10th Pass     1168500        9000     0.0
# 2258              0  GENERAL  Post Graduate     4890000     1020000     0.0
# 2259             18  GENERAL       Graduate  1287851556    11535000     1.0
# 2260              0  GENERAL  Post Graduate   903663001           0     0.0
# 2261              3  GENERAL      12th Pass    58577327     5250000     0.0
#
#        AGE  GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 0     52.0       376892.0         482.0     377374.0
# 1     54.0       318665.0         149.0     318814.0
# 2     52.0       314057.0         181.0     314238.0
# 4     58.0       644459.0        2416.0     646875.0
# 5     47.0       434199.0        1130.0     435329.0
# ...    ...            ...           ...          ...
# 2257  28.0        20563.0          57.0      20620.0
# 2258  43.0        14661.0          25.0      14686.0
# 2259  63.0       434066.0         178.0     434244.0
# 2260  49.0       427900.0         115.0     428015.0
# 2261  47.0       138731.0         216.0     138947.0
#
#       OVER TOTAL ELECTORS IN CONSTITUENCY  \
# 0                               25.330684
# 1                               21.399929
# 2                               21.092771
# 4                               33.383823
# 5                               22.466390
# ...                                   ...
# 2257                             1.076097
# 2258                             0.766419
# 2259                            28.975369
# 2260                            28.559732
# 2261                             9.271379
#
#       OVER TOTAL VOTES POLLED IN CONSTITUENCY  TOTAL ELECTORS  GENDER
# 0                                   35.468248       1489790.0    MALE
# 1                                   29.964370       1489790.0    MALE
# 2                                   29.534285       1489790.0    MALE
# 4                                   56.464615       1937690.0    MALE
# 5                                   37.999125       1937690.0    MALE
# ...                                       ...             ...     ...
# 2257                                 1.755157       1916185.0  FEMALE
# 2258                                 1.250060       1916185.0    MALE
# 2259                                41.574183       1498666.0    MALE
# 2260                                40.977823       1498666.0    MALE
# 2261                                13.302678       1498666.0    MALE
#
# [2018 rows x 19 columns]
